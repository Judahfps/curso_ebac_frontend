# %% [markdown]
# <a href="https://colab.research.google.com/github/Judahfps/curso_ebac_frontend/blob/main/C%C3%B3pia_de_Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hi = 'Hello World!'
print(hi)

# %% [markdown]
# ![kaliLinux.png](data:image/png;base64,...)

# %%
valor_total_de_vendas = ''
qnt_total_de_vendas = 3
ticket_medio = 320.52
A = ticket_medio * qnt_total_de_vendas
print(A)


valor_total_de_vendas = 834.47
qnt_total_de_vendas = ''
ticket_medio = 119.21
B = valor_total_de_vendas // ticket_medio
print(int(B))

valor_total_de_vendas = 15378.12
qnt_total_de_vendas = 5
ticket_medio = ''
C = valor_total_de_vendas // qnt_total_de_vendas
print(int(C))

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião'
print(cancao.upper())
print(cancao.find('moinho'))
print(cancao.replace('mundo', 'o universo'))

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; ' + 'é a primeira alta em 6 anos'
print(noticia[12:17])
print(noticia[-6])

# %%
a = False
b = True
x = not a & b
print(x)
# x= True
